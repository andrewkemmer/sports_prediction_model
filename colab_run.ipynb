# %% [markdown]
# <a href="https://colab.research.google.com/github/andrewkemmer/sports_prediction_model/blob/main/colab_run.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os, sys
os.chdir('/content')
# !rm -rf sports_prediction_model
# !git clone https://github.com/andrewkemmer/sports_prediction_model.git
os.chdir('sports_prediction_model/mlb-bet-predictor')
sys.path.insert(0, 'backend')

from datetime import date
from pipeline import run_daily_pipeline

summary = run_daily_pipeline(date(2026, 8, 9), real=True, skip_sync=True)
print("Status:", summary["status"])
# Out:
# Cloning into 'sports_prediction_model'...
# remote: Enumerating objects: 87, done.
# remote: Counting objects: 100% (87/87), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 87 (delta 31), reused 34 (delta 14), pack-reused 0 (from 0)
# Receiving objects: 100% (87/87), 166.83 KiB | 1.83 MiB/s, done.
# Resolving deltas: 100% (31/31), done.
# WARNING:data_ingestion:Failed to fetch schedule for NYY: Data cannot be retrieved for this team/year combo. Please verify that your team abbreviation is accurate and that the team existed during the season you are searching for.
# http://www.baseball-reference.com/teams/NYY/2026-schedule-scores.shtml
# http://www.baseball-reference.com/teams/BOS/2026-schedule-scores.shtml
# WARNING:data_ingestion:Failed to fetch schedule for BOS: Data cannot be retrieved for this team/year combo. Please verify that your team abbreviation is accurate and that the team existed during the season you are searching for.
# ...
