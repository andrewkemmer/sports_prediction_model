# %% [markdown]
# <a href="https://colab.research.google.com/github/andrewkemmer/sports_prediction_model/blob/main/colab_run.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import userdata
os.environ["GITHUB_TOKEN"] = userdata.get("MY_GITHUB_TOKEN")   # for Phase 5 sync

# optional — only when you want a custom window:
os.environ["MLB_START_DATE"] = "2025-01-01"
os.environ["MLB_END_DATE"] = "2026-08-24"   # omit = runs through today
os.environ["MLB_FULL_REPULL"] = "1"   # next run only, then remove

# !rm -rf /content/sports_prediction_model && git clone -q https://github.com/andrewkemmer/sports_prediction_model.git /content/sports_prediction_model && python /content/sports_prediction_model/mlb-bet-predictor/backend/master_pipeline.py
# Out:
# 🔑 GitHub token loaded from environment
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   PHASE 0 — Environment Setup
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 📦 Installing dependencies...
#   ✅ Done
#   🔄 Removing old clone...
# 📥 Cloning sports_prediction_model...
#   📁 /content/sports_prediction_model/mlb-bet-predictor
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   PHASE 1 — Statcast Data Ingestion
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 📅 2025-01-01 → 2026-08-23
#   ♻️  MLB_FULL_REPULL set — discarding cache and re-pulling full history
#   INFO Pulling Statcast: 2025-01-01 → 2026-08-23 (chunk_days=60)
#   INFO   Chunk: 2025-01-01 → 2025-03-01
# This is a large query, it may take a moment to complete
# Skipping offseason dates
# 0it [00:00, ?it/s]
#   INFO   Chunk: 2025-03-02 → 2025-04-30
# This is a large query, it may take a moment to complete
# Skipping offseason dates
# 100% 47/47 [00:39<00:00,  1.18it/s]
#   INFO     → 178575 pitches
#   INFO   Chunk: 2025-05-01 → 2025-06-29
# This is a large query, it may take a moment to complete
# 100% 60/60 [01:10<00:00,  1.18s/it]
#   INFO     → 233774 pitches
#   INFO   Chunk: 2025-06-30 → 2025-08-28
# This is a large query, it may take a moment to complete
# 100% 60/60 [01:18<00:00,  1.30s/it]
#   INFO     → 220389 pitches
#   INFO   Chunk: 2025-08-29 → 2025-10-27
# This is a large query, it may take a moment to complete
# 100% 60/60 [00:41<00:00,  1.45it/s]
#   INFO     → 136812 pitches
#   INFO   Chunk: 2025-10-28 → 2025-12-26
# This is a large query, it may take a moment to complete
# Skipping offseason dates
# 100% 19/19 [00:00<00:00, 23.16it/s]
#   INFO     → 1245 pitches
#   INFO   Chunk: 2025-12-27 → 2026-02-24
# This is a large query, it may take a moment to complete
# Skipping offseason dates
# 0it [00:00, ?it/s]
#   INFO   Chunk: 2026-02-25 → 2026-04-25
# This is a large query, it may take a moment to complete
# Skipping offseason dates
# 100% 42/42 [00:33<00:00,  1.24it/s]
#   INFO     → 159424 pitches
#   INFO   Chunk: 2026-04-26 → 2026-06-24
# This is a large query, it may take a moment to complete
# 100% 60/60 [00:46<00:00,  1.30it/s]
#   INFO     → 232729 pitches
#   INFO   Chunk: 2026-06-25 → 2026-08-23
# This is a large query, it may take a moment to complete
# 100% 60/60 [00:48<00:00,  1.24it/s]
#   INFO     → 220463 pitches
#   INFO Total raw pitches: 1383411
#   INFO Dropped 82019 non-regular-season pitches (game_type S/E)
#   INFO Saved 1301392 pitches → /content/mlb_clean_data/pitches.parquet (133.9 MB)
#   ✅ Raw pitches: /content/mlb_clean_data/pitches.parquet
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   PHASE 2-3 — DuckDB Feature Engineering (pure SQL)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#   INFO === DuckDB Feature Engineering ===
#   INFO [MEM] Start: 3744 MB
#   INFO [MEM] After DuckDB load: 3744 MB
#   INFO Building game-level features...
#   INFO game_level built: 4426 games
#   INFO [MEM] After game_level: 3744 MB
#   INFO Exported game_level: 2.5 MB
#   INFO Building PBP-level features...
#   INFO pbp_level built: 1301392 pitches
#   INFO [MEM] After pbp_level: 3744 MB
#   INFO Exported pbp_level: 31.2 MB
#   INFO [MEM] After DuckDB close: 3744 MB
#   INFO Official results applied: 4426 games verified/corrected
#   INFO [MEM] After pandas load: 3744 MB
#   INFO Computing 35 diff features for 4426 games...
#   WARNING win_pct_diff: record/win-pct columns missing, set to NaN
#   INFO Diff features complete: 35 columns added
#   INFO === Complete: 4426 games, 1301392 pitches ===
#   ✅ Game: (4426, 116)
#   ✅ PBP:  (1301392, 88)
#   INFO Computing 35 diff features for 4426 games...
#   INFO Diff features complete: 35 columns added
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   PHASE 3.5 — Save Features
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#   📄 CSV: 5.0 MB
#   📄 Parquet: 29.5 MB
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   PHASE 4 — Training + Prediction
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#   INFO Loaded 4426 games from game_level_features.csv (columns: ['game_pk', 'game_date', 'home_team', 'away_team', 'home_score', 'away_score', 'home_win', 'total_runs', 'home_starter_id', 'away_starter_id', 'venue', 'rest_days_home', 'rest_days_away', 'sp_era_home', 'sp_k9_home', 'sp_bb9_home', 'sp_whip_home', 'sp_fip_home', 'sp_xwoba_home', 'sp_era_away', 'sp_k9_away', 'sp_bb9_away', 'sp_whip_away', 'sp_fip_away', 'sp_xwoba_away', 'sp_era_30g_home', 'sp_k9_30g_home', 'sp_era_30g_away', 'sp_k9_30g_away', 'woba_30g_home', 'team_iso_30g_home', 'team_k_rate_30g_home', 'team_bb_rate_30g_home', 'woba_30g_away', 'team_iso_30g_away', 'team_k_rate_30g_away', 'team_bb_rate_30g_away', 'bullpen_whip_10g_home', 'bullpen_era_10g_home', 'bullpen_whip_10g_away', 'bullpen_era_10g_away', 'bullpen_whip_3g_home', 'bullpen_whip_3g_away', 'sp_fbvelo_3g_home', 'sp_fbpct_3g_home', 'sp_whiff_3g_home', 'sp_xwoba_vs_l_home', 'sp_xwoba_vs_r_home', 'sp_fbvelo_3g_away', 'sp_fbpct_3g_away', 'sp_whiff_3g_away', 'sp_xwoba_vs_l_away', 'sp_xwoba_vs_r_away', 'team_barrel_15g_home', 'team_hardhit_15g_home', 'team_exitvelo_15g_home', 'team_barrel_15g_away', 'team_hardhit_15g_away', 'team_exitvelo_15g_away', 'opp_lefty_share_home', 'opp_lefty_share_away', 'bullpen_pitches_3d_home', 'bullpen_ip_3d_home', 'bullpen_pitches_3d_away', 'bullpen_ip_3d_away', 'lineup_ops_vs_l_home', 'lineup_ops_vs_r_home', 'lineup_ops_vs_l_away', 'lineup_ops_vs_r_away', 'lineup_ops_vs_starter_hand_home', 'lineup_ops_vs_starter_hand_away', 'time_zones_crossed_last_3d_home', 'time_zones_crossed_last_3d_away', 'closer_available_home', 'closer_available_away', 'lineup_woba_mean_home', 'lineup_woba_top3_home', 'lineup_woba_std_home', 'lineup_woba_mean_away', 'lineup_woba_top3_away', 'lineup_woba_std_away', 'is_home', 'win_pct_diff', 'elo_diff', 'rest_days_diff', 'sp_era_diff', 'sp_era_30g_diff', 'sp_k9_diff', 'sp_k9_30g_diff', 'sp_fbvelo_diff', 'sp_fbpct_diff', 'sp_whiff_diff', 'sp_xwoba_diff', 'sp_xwoba_vs_l_diff', 'lineup_woba_mean_diff', 'lineup_woba_top3_diff', 'lineup_woba_std_diff', 'woba_30g_diff', 'bullpen_whip_diff', 'bullpen_whip_3g_diff', 'bullpen_pitches_diff', 'bullpen_ip_diff', 'team_barrel_diff', 'team_hardhit_diff', 'team_exitvelo_diff', 'lineup_handedness_matchup_advantage', 'travel_fatigue_diff', 'closer_availability_diff', 'dome_is_neutral', 'park_factor_slug_diff', 'wind_advantage_flyball_factor', 'air_density_velocity_boost', 'bullpen_meltdown_risk', 'pitcher_regression_indicator', 'lineup_depth_multiplier', 'ace_efficiency_factor', 'home_elo', 'away_elo', 'home_wins', 'home_losses', 'away_wins', 'away_losses', 'home_win_pct', 'away_win_pct', 'home_run_diff', 'away_run_diff', 'home_record', 'away_record'])
#   INFO Feature mapping complete: 4426 games, columns: ['game_pk', 'game_date', 'home_team', 'away_team', 'home_score', 'away_score', 'home_win', 'total_runs', 'home_starter_id', 'away_starter_id', 'venue', 'rest_days_home', 'rest_days_away', 'sp_era_home', 'sp_k9_home', 'sp_bb9_home', 'sp_whip_home', 'sp_fip_home', 'sp_xwoba_home', 'sp_era_away', 'sp_k9_away', 'sp_bb9_away', 'sp_whip_away', 'sp_fip_away', 'sp_xwoba_away', 'sp_era_30g_home', 'sp_k9_30g_home', 'sp_era_30g_away', 'sp_k9_30g_away', 'woba_30g_home', 'team_iso_30g_home', 'team_k_rate_30g_home', 'team_bb_rate_30g_home', 'woba_30g_away', 'team_iso_30g_away', 'team_k_rate_30g_away', 'team_bb_rate_30g_away', 'bullpen_whip_10g_home', 'bullpen_era_10g_home', 'bullpen_whip_10g_away', 'bullpen_era_10g_away', 'bullpen_whip_3g_home', 'bullpen_whip_3g_away', 'sp_fbvelo_3g_home', 'sp_fbpct_3g_home', 'sp_whiff_3g_home', 'sp_xwoba_vs_l_home', 'sp_xwoba_vs_r_home', 'sp_fbvelo_3g_away', 'sp_fbpct_3g_away', 'sp_whiff_3g_away', 'sp_xwoba_vs_l_away', 'sp_xwoba_vs_r_away', 'team_barrel_15g_home', 'team_hardhit_15g_home', 'team_exitvelo_15g_home', 'team_barrel_15g_away', 'team_hardhit_15g_away', 'team_exitvelo_15g_away', 'opp_lefty_share_home', 'opp_lefty_share_away', 'bullpen_pitches_3d_home', 'bullpen_ip_3d_home', 'bullpen_pitches_3d_away', 'bullpen_ip_3d_away', 'lineup_ops_vs_l_home', 'lineup_ops_vs_r_home', 'lineup_ops_vs_l_away', 'lineup_ops_vs_r_away', 'lineup_ops_vs_starter_hand_home', 'lineup_ops_vs_starter_hand_away', 'time_zones_crossed_last_3d_home', 'time_zones_crossed_last_3d_away', 'closer_available_home', 'closer_available_away', 'lineup_woba_mean_home', 'lineup_woba_top3_home', 'lineup_woba_std_home', 'lineup_woba_mean_away', 'lineup_woba_top3_away', 'lineup_woba_std_away', 'is_home', 'win_pct_diff', 'elo_diff', 'rest_days_diff', 'sp_era_diff', 'sp_era_30g_diff', 'sp_k9_diff', 'sp_k9_30g_diff', 'sp_fbvelo_diff', 'sp_fbpct_diff', 'sp_whiff_diff', 'sp_xwoba_diff', 'sp_xwoba_vs_l_diff', 'lineup_woba_mean_diff', 'lineup_woba_top3_diff', 'lineup_woba_std_diff', 'woba_30g_diff', 'bullpen_whip_diff', 'bullpen_whip_3g_diff', 'bullpen_pitches_diff', 'bullpen_ip_diff', 'team_barrel_diff', 'team_hardhit_diff', 'team_exitvelo_diff', 'lineup_handedness_matchup_advantage', 'travel_fatigue_diff', 'closer_availability_diff', 'dome_is_neutral', 'park_factor_slug_diff', 'wind_advantage_flyball_factor', 'air_density_velocity_boost', 'bullpen_meltdown_risk', 'pitcher_regression_indicator', 'lineup_depth_multiplier', 'ace_efficiency_factor', 'home_elo', 'away_elo', 'home_wins', 'home_losses', 'away_wins', 'away_losses', 'home_win_pct', 'away_win_pct', 'home_run_diff', 'away_run_diff', 'home_record', 'away_record', 'game_id', 'start_time_utc', 'start_time_observed']
#   📋 Training data: 4426 games, 131 features
#   📊 Feature coverage: home_elo:100%, home_win_pct:99%, sp_era_30g_home:97%, woba_30g_home:100%, bullpen_whip_10g_home:99%, rest_days_home:99%
#   INFO === Daily pipeline for 20260823 (model v2026.08.23) ===
#   INFO Step 1: Using pre-built game features (4426 games)
#   INFO Loaded 4426 games
#   INFO Official results applied: 4426 games verified/corrected
#   INFO Weather fetched: 475/475 games
#   INFO Weather backfill: 475/475 decided games matched to real starts
#   INFO Weather features applied to 329/4426 games
#   INFO Step 2: Generating market lines
#   INFO Step 3: Walk-forward evaluation
#   INFO Fold 0 [2025-04-24 → 2025-04-30]: train=366 val=92 auc=0.5208 brier=0.2757
#   INFO Fold 1 [2025-05-01 → 2025-05-07]: train=458 val=95 auc=0.5724 brier=0.2582
#   INFO Fold 2 [2025-05-08 → 2025-05-14]: train=553 val=95 auc=0.5656 brier=0.2640
#   INFO Fold 3 [2025-05-15 → 2025-05-21]: train=648 val=91 auc=0.5933 brier=0.2611
#   INFO Fold 4 [2025-05-22 → 2025-05-28]: train=739 val=95 auc=0.5777 brier=0.2479
#   INFO Calibration: Platt fitted on 373 OOF games (a=0.3265, b=-0.1065)
#   INFO Fold 5 [2025-05-29 → 2025-06-04]: train=834 val=86 auc=0.5255 brier=0.2728
#   INFO Calibration: Platt fitted on 468 OOF games (a=0.3296, b=-0.0548)
#   INFO Fold 6 [2025-06-05 → 2025-06-11]: train=920 val=97 auc=0.5383 brier=0.2523
#   INFO Calibration: Platt fitted on 554 OOF games (a=0.3116, b=-0.0774)
#   INFO Fold 7 [2025-06-12 → 2025-06-18]: train=1017 val=87 auc=0.5303 brier=0.2556
#   INFO Calibration: Platt fitted on 651 OOF games (a=0.2920, b=-0.0283)
#   INFO Fold 8 [2025-06-19 → 2025-06-25]: train=1104 val=100 auc=0.5167 brier=0.2658
#   INFO Calibration: Platt fitted on 738 OOF games (a=0.2768, b=0.0066)
#   INFO Fold 9 [2025-06-26 → 2025-07-02]: train=1204 val=92 auc=0.4816 brier=0.2650
#   INFO Calibration: Platt fitted on 838 OOF games (a=0.2714, b=-0.0102)
#   INFO Fold 10 [2025-07-03 → 2025-07-09]: train=1296 val=94 auc=0.4637 brier=0.2730
#   INFO Calibration: Platt fitted on 930 OOF games (a=0.2505, b=0.0142)
#   INFO Fold 11 [2025-07-10 → 2025-07-20]: train=1390 val=101 auc=0.4478 brier=0.2695
#   INFO Calibration: Platt fitted on 1024 OOF games (a=0.2123, b=0.0345)
#   INFO Fold 12 [2025-07-21 → 2025-07-27]: train=1491 val=95 auc=0.4033 brier=0.2792
#   INFO Calibration: Platt fitted on 1125 OOF games (a=0.1836, b=0.0534)
#   INFO Fold 13 [2025-07-28 → 2025-08-03]: train=1586 val=93 auc=0.4872 brier=0.2643
#   INFO Calibration: Platt fitted on 1220 OOF games (a=0.1449, b=0.0684)
#   INFO Fold 14 [2025-08-04 → 2025-08-10]: train=1679 val=93 auc=0.5796 brier=0.2454
#   INFO Calibration: Platt fitted on 1313 OOF games (a=0.1320, b=0.0869)
#   INFO Fold 15 [2025-08-11 → 2025-08-17]: train=1772 val=93 auc=0.5228 brier=0.2559
#   INFO Calibration: Platt fitted on 1406 OOF games (a=0.1549, b=0.0726)
#   INFO Fold 16 [2025-08-18 → 2025-08-24]: train=1865 val=95 auc=0.5711 brier=0.2452
#   INFO Calibration: Platt fitted on 1499 OOF games (a=0.1561, b=0.0754)
#   INFO Fold 17 [2025-08-25 → 2025-08-31]: train=1960 val=96 auc=0.4881 brier=0.2601
#   INFO Calibration: Platt fitted on 1594 OOF games (a=0.1686, b=0.0780)
#   INFO Fold 18 [2025-09-01 → 2025-09-07]: train=2056 val=93 auc=0.4787 brier=0.2672
#   INFO Calibration: Platt fitted on 1690 OOF games (a=0.1630, b=0.0757)
#   INFO Fold 19 [2025-09-08 → 2025-09-14]: train=2149 val=95 auc=0.5091 brier=0.2419
#   INFO Calibration: Platt fitted on 1783 OOF games (a=0.1560, b=0.0663)
#   INFO Fold 20 [2025-09-15 → 2025-09-21]: train=2244 val=96 auc=0.5637 brier=0.2506
#   INFO Calibration: Platt fitted on 1878 OOF games (a=0.1531, b=0.0973)
#   INFO Fold 21 [2025-09-22 → 2025-09-28]: train=2340 val=90 auc=0.5864 brier=0.2333
#   INFO Calibration: Platt fitted on 1974 OOF games (a=0.1746, b=0.0694)
#   INFO Skipping fold 22 [2025-09-30 → 2025-10-07]: only 21 val games < 40 minimum
#   INFO Skipping fold 23 [2025-10-08 → 2025-10-14]: only 12 val games < 40 minimum
#   INFO Skipping fold 24 [2025-10-15 → 2025-10-25]: only 9 val games < 40 minimum
#   INFO Skipping fold 25 [2025-10-27 → 2026-03-26]: only 17 val games < 40 minimum
#   INFO Fold 26 [2026-03-27 → 2026-04-02]: train=2489 val=82 auc=0.4881 brier=0.2478
#   INFO Calibration: Platt fitted on 2064 OOF games (a=0.1973, b=0.0746)
#   INFO Fold 27 [2026-04-03 → 2026-04-09]: train=2571 val=94 auc=0.4044 brier=0.2738
#   INFO Calibration: Platt fitted on 2146 OOF games (a=0.1939, b=0.0875)
#   INFO Fold 28 [2026-04-10 → 2026-04-16]: train=2665 val=95 auc=0.4693 brier=0.2531
#   INFO Calibration: Platt fitted on 2240 OOF games (a=0.1733, b=0.0892)
#   INFO Fold 29 [2026-04-17 → 2026-04-23]: train=2760 val=94 auc=0.4768 brier=0.2659
#   INFO Calibration: Platt fitted on 2335 OOF games (a=0.1674, b=0.0999)
#   INFO Fold 30 [2026-04-24 → 2026-04-30]: train=2854 val=91 auc=0.4918 brier=0.2638
#   INFO Calibration: Platt fitted on 2429 OOF games (a=0.1622, b=0.0915)
#   INFO Fold 31 [2026-05-01 → 2026-05-07]: train=2945 val=95 auc=0.6775 brier=0.2333
#   INFO Calibration: Platt fitted on 2520 OOF games (a=0.1544, b=0.0910)
#   INFO Fold 32 [2026-05-08 → 2026-05-14]: train=3040 val=91 auc=0.5424 brier=0.2507
#   INFO Calibration: Platt fitted on 2615 OOF games (a=0.1798, b=0.0831)
#   INFO Fold 33 [2026-05-15 → 2026-05-21]: train=3131 val=96 auc=0.6545 brier=0.2430
#   INFO Calibration: Platt fitted on 2706 OOF games (a=0.1739, b=0.0949)
#   INFO Fold 34 [2026-05-22 → 2026-05-28]: train=3227 val=92 auc=0.5175 brier=0.2513
#   INFO Calibration: Platt fitted on 2802 OOF games (a=0.1972, b=0.0754)
#   INFO Fold 35 [2026-05-29 → 2026-06-04]: train=3319 val=93 auc=0.4552 brier=0.2595
#   INFO Calibration: Platt fitted on 2894 OOF games (a=0.2070, b=0.0674)
#   INFO Fold 36 [2026-06-05 → 2026-06-11]: train=3412 val=89 auc=0.5497 brier=0.2485
#   INFO Calibration: Platt fitted on 2987 OOF games (a=0.2007, b=0.0712)
#   INFO Fold 37 [2026-06-12 → 2026-06-18]: train=3501 val=91 auc=0.4732 brier=0.2632
#   INFO Calibration: Platt fitted on 3076 OOF games (a=0.2022, b=0.0758)
#   INFO Fold 38 [2026-06-19 → 2026-06-25]: train=3592 val=93 auc=0.5236 brier=0.2551
#   INFO Calibration: Platt fitted on 3167 OOF games (a=0.1910, b=0.0808)
#   INFO Fold 39 [2026-06-26 → 2026-07-02]: train=3685 val=96 auc=0.5532 brier=0.2479
#   INFO Calibration: Platt fitted on 3260 OOF games (a=0.1916, b=0.0781)
#   INFO Fold 40 [2026-07-03 → 2026-07-09]: train=3781 val=95 auc=0.5646 brier=0.2517
#   INFO Calibration: Platt fitted on 3356 OOF games (a=0.1992, b=0.0750)
#   INFO Fold 41 [2026-07-10 → 2026-07-19]: train=3876 val=91 auc=0.5662 brier=0.2476
#   INFO Calibration: Platt fitted on 3451 OOF games (a=0.2071, b=0.0667)
#   INFO Fold 42 [2026-07-20 → 2026-07-26]: train=3967 val=95 auc=0.4964 brier=0.2637
#   INFO Calibration: Platt fitted on 3542 OOF games (a=0.2130, b=0.0647)
#   INFO Fold 43 [2026-07-27 → 2026-08-02]: train=4062 val=97 auc=0.5804 brier=0.2453
#   INFO Calibration: Platt fitted on 3637 OOF games (a=0.2057, b=0.0657)
#   INFO Fold 44 [2026-08-03 → 2026-08-09]: train=4159 val=94 auc=0.4796 brier=0.2596
#   INFO Calibration: Platt fitted on 3734 OOF games (a=0.2140, b=0.0633)
#   INFO Fold 45 [2026-08-10 → 2026-08-16]: train=4253 val=93 auc=0.4884 brier=0.2631
#   INFO Calibration: Platt fitted on 3828 OOF games (a=0.2060, b=0.0699)
#   INFO Fold 46 [2026-08-17 → 2026-08-22]: train=4346 val=80 auc=0.4883 brier=0.2478
#   INFO Calibration: Platt fitted on 3921 OOF games (a=0.2042, b=0.0673)
#   INFO Calibration: Platt fitted on 4001 OOF games (a=0.2002, b=0.0779)
#   INFO Calibration (OOF, prequential): ECE 0.0684 → 0.0049, log-loss 0.7087 → 0.6909
#   INFO Adaptive ensemble weights: {'lightgbm': '5.0%', 'logistic': '31.5%', 'mlp': '19.3%', 'randomforest': '39.2%', 'xgboost': '5.0%'}
#   INFO Walk-forward metrics: {'auc': 0.5249, 'brier': 0.2568, 'logloss': 0.7087, 'ece': 0.0684, 'brier_calibrated': 0.2489, 'logloss_calibrated': 0.6909, 'ece_calibrated': 0.0049}
#   INFO Ensemble persisted to /content/sports_prediction_model/mlb-bet-predictor/data_delivery/models/ensemble_latest.joblib
#   INFO Step 4: Predicting games for 20260823
#   INFO Upcoming slate built: 15 games for 2026-08-23
#   INFO No completed games on 20260823 — built 15-game upcoming slate (pre-game PIT features)
#   INFO Weather fetched: 15/15 games
#   INFO Computing 35 diff features for 15 games...
#   INFO Weather applied to 15/15 games
#   INFO Diff features complete: 35 columns added
#   INFO Step 5: Writing artifacts
#   INFO Prediction history written: 4001 games -> predictions_history_20260823.csv
#   INFO Step 6: Explainability
#   INFO SHAP attributions written for 15 games
#   INFO Feature drift: 35 features, 0 warnings, 0 alerts (statuses on noise-adjusted PSI; mean noise floor 0.063)
#   INFO Step 7: Skipping GitHub sync
#   INFO === Pipeline complete: ok ===
#   📊 Status: ok
#   📈 Metrics: {
#   "auc": 0.5249,
#   "brier": 0.2568,
#   "logloss": 0.7087,
#   "ece": 0.0684,
#   "brier_calibrated": 0.2489,
#   "logloss_calibrated": 0.6909,
#   "ece_calibrated": 0.0049
# }
#   📁 Artifacts: 6 files
#     /content/sports_prediction_model/mlb-bet-predictor/data_delivery/todays_games_20260823.csv
#     /content/sports_prediction_model/mlb-bet-predictor/data_delivery/power_rankings_20260823.csv
#     /content/sports_prediction_model/mlb-bet-predictor/data_delivery/calibration_20260823.json
#     /content/sports_prediction_model/mlb-bet-predictor/data_delivery/predictions_history_20260823.csv
#     /content/sports_prediction_model/mlb-bet-predictor/data_delivery/feature_drift_20260823.csv
#     /content/sports_prediction_model/mlb-bet-predictor/data_delivery/model_monitor_20260823.json
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   PHASE 5 — GitHub Sync — push new artifacts
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#   📋 Staging 24 files:
#     mlb-bet-predictor/data_delivery/game_level_features.csv
#     mlb-bet-predictor/data_delivery/calibration_20260823.json
#     mlb-bet-predictor/data_delivery/feature_drift_20260823.csv
#     mlb-bet-predictor/data_delivery/model_history.json
#     mlb-bet-predictor/data_delivery/model_monitor_20260823.json
#     mlb-bet-predictor/data_delivery/models/ensemble_latest.joblib
#     mlb-bet-predictor/data_delivery/power_rankings_20260823.csv
#     mlb-bet-predictor/data_delivery/predictions_history_20260823.csv
#     mlb-bet-predictor/data_delivery/shap_game_20260823_ATH@HOU.csv
#     mlb-bet-predictor/data_delivery/shap_game_20260823_ATL@MIL.csv
#     mlb-bet-predictor/data_delivery/shap_game_20260823_CHC@SEA.csv
#     mlb-bet-predictor/data_delivery/shap_game_20260823_CIN@ARI.csv
#     mlb-bet-predictor/data_delivery/shap_game_20260823_CLE@COL.csv
#     mlb-bet-predictor/data_delivery/shap_game_20260823_DET@KC.csv
#     mlb-bet-predictor/data_delivery/shap_game_20260823_LAA@TEX.csv
#     mlb-bet-predictor/data_delivery/shap_game_20260823_MIN@SD.csv
#     mlb-bet-predictor/data_delivery/shap_game_20260823_NYM@CHW.csv
#     mlb-bet-predictor/data_delivery/shap_game_20260823_PIT@LAD.csv
#     mlb-bet-predictor/data_delivery/shap_game_20260823_SF@BOS.csv
#     mlb-bet-predictor/data_delivery/shap_game_20260823_STL@PHI.csv
#     mlb-bet-predictor/data_delivery/shap_game_20260823_TB@BAL.csv
#     mlb-bet-predictor/data_delivery/shap_game_20260823_TOR@NYY.csv
#     mlb-bet-predictor/data_delivery/shap_game_20260823_WSH@MIA.csv
#     mlb-bet-predictor/data_delivery/todays_games_20260823.csv
#   ✅ Pushed 24 files — confirmed on sports_prediction_model@main
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   PHASE 6 — Stale artifact cleanup (final step)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#   ✅ No stale files — data_delivery holds exactly this run's artifacts
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   DONE ✅ —
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#   Games: 4426  |  Pitches: 1,301,392  |  Features: 216
#   Output: /content/mlb_clean_data
